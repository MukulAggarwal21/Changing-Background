# %% [markdown]
# <a href="https://colab.research.google.com/github/MukulAggarwal21/Changing-Background/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib. pyplot as plt
n=np.array([1,3])
m=np.array([3,7])
# plt.nlabel(xaxis)
# plt.mlabel(yaxis)
plt.plot (n,m)
plt.grid(axis='x')
plt.grid(color='red', linestyle='-', linewidth=2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x1=([1,6,8])
x2=([2,4,9])
plt.subplot(1,2,1)
plt.plot(x1,x2)
plt.title('plot one')
x3=([5,4,5])
x4=([8,7,9])
plt.subplot(1,2,2)
plt.plot(x3,x4)
plt.title('plot two')
plt.suptitle('my plot')
# Out:
# Text(0.5, 0.98, 'my plot')

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([4,5,6])
y = np.array([7,8,9])
plt.scatter(x,y, color='r' )
x1= np.array([5,7,9])
y2 = np.array([10,11,12])
plt.scatter(x1,y2)
plt.show()
