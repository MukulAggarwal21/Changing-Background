# %% [markdown]
# <a href="https://colab.research.google.com/github/MukulAggarwal21/Changing-Background/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([2,4,6,9])
y=np.array([7,4,1,8])
c1=np.array(['red','yellow','red','yellow'])
# size = np.array ([4])
plt.scatter(x,y,c=c1)
plt.show ()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([2, 4, 6, 9])
y = np.array([7, 4, 1, 8])
c1 = np.array(['red', 'yellow', 'green', 'blue'])  # Adjust the size of c1 to match the size of x and y

plt.scatter(x, y, c=c1)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(['A' , 'B' , 'C'])
y = np.array([3,16,4])
plt.bar(x,y,color='r',width=0.8)
plt.show()
